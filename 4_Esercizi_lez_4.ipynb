# %% [markdown]
# ## 1. La legge dei grandi numeri
#
# La legge dei grandi numeri è un teorema fondamentale della teoria della probabilità che indica che se ripetiamo molte volte (tendendo all'infinito) lo stesso esperimento, la frequenza di un certo evento tende ad essere costante.
#
# Vale a dire, **la legge dei grandi numeri indica che se lo stesso test viene eseguito ripetutamente (ad esempio, lancio di una moneta), la frequenza con cui si ripeterà un determinato evento (testa/croce) si avvicinerà a una costante. Questa a sua volta sarà la probabilità che questo evento si verifichi.**
#
# Fonte: https://it.economy-pedia.com/11038376-law-of-the-big-numbers
#
# - Scrivere una funzione che simula il lancio di una moneta per N volte e restituisce la frequenza % di volte che è uscita testa.
# - Calcolare la frequenza % con la grandezze del campione (numero di lanci) che varia 100 volte da 10 a 20000. Ottengo quindi 100 valori.
# - Fare il plot del Numero medio di teste (y) rispetto alla grandezza del campione (x)

# %%
import matplotlib.pyplot as plt
import numpy as np

# Simulazione del lancio di una moneta
def lancia_moneta(n):
    x=np.random.randint(0, 2, n)
    freq_testa=x.mean()*100
    return freq_testa

n = 1000
m=lancia_moneta(n)
print("La percentuale di volte che è uscito testa è: ", m, "%")


# Simulazione del lancio di una moneta con un numero variabile di lanci
num=np.random.randint(10, 20001, 100)    #lista di numeri casuali
mon=[]     #lista per memorizzare le percentuali
for i in num:
    m=lancia_moneta(i)
    mon.append(m)
    print("La percentuale di volte che è uscito testa su ", i, "lanci è: ", m, "%")

# Grafico della percentuale di testa in funzione del numero di lanci
plt.plot(num, mon, marker='o', color="blue", label="Frequenza testa")
plt.xlabel("Numero di lanci")
plt.ylabel("Percentuale (%)")
plt.legend()
plt.show()
# Out:
# La percentuale di volte che è uscito testa è:  53.1 %
# La percentuale di volte che è uscito testa su  14524 lanci è:  50.0 %
# La percentuale di volte che è uscito testa su  17898 lanci è:  50.094982679629005 %
# La percentuale di volte che è uscito testa su  18250 lanci è:  50.252054794520554 %
# La percentuale di volte che è uscito testa su  3481 lanci è:  49.152542372881356 %
# La percentuale di volte che è uscito testa su  2137 lanci è:  50.25737014506318 %
# La percentuale di volte che è uscito testa su  2194 lanci è:  48.495897903372835 %
# La percentuale di volte che è uscito testa su  10346 lanci è:  49.516721438237 %
# La percentuale di volte che è uscito testa su  12207 lanci è:  50.69222577209798 %
# La percentuale di volte che è uscito testa su  10711 lanci è:  50.55550368779759 %
# La percentuale di volte che è uscito testa su  15669 lanci è:  50.25847214244688 %
# La percentuale di volte che è uscito testa su  815 lanci è:  51.77914110429448 %
# La percentuale di volte che è uscito testa su  7357 lanci è:  49.109691450319424 %
# La percentuale di volte che è uscito testa su  18029 lanci è:  50.307837373121075 %
# La percentuale di volte che è uscito testa su  6305 lanci è:  49.817605075337035 %
# La percentuale di volte che è uscito testa su  836 lanci è:  53.110047846889955 %
# La percentuale di volte che è uscito testa su  3698 lanci è:  49.945916711736075 %
# La percentuale di volte che è uscito testa su  10358 lanci è:  50.52133616528287 %
# La percentuale di volte che è uscito testa su  13085 lanci è:  50.92090179594956 %
# La percentuale di volte che è uscito testa su  17282 lanci è:  50.06365004050457 %
# La percentuale di volte che è uscito testa su  13658 lanci è:  49.86820910821497 %
# La percentuale di volte che è uscito testa su  7575 lanci è:  49.254125412541256 %
# La percentuale di volte che è uscito testa su  1998 lanci è:  51.1011011011011 %
# La percentuale di volte che è uscito testa su  14358 lanci è:  49.338347959325816 %
# La percentuale di volte che è uscito testa su  18349 lanci è:  50.54226388359039 %
# La percentuale di volte che è uscito testa su  18383 lanci è:  49.82320622314095 %
# La percentuale di volte che è uscito testa su  4385 lanci è:  49.236031927023944 %
# La percentuale di volte che è uscito testa su  12801 lanci è:  49.26958831341302 %
# La percentuale di volte che è uscito testa su  17372 lanci è:  49.91365415611328 %
# La percentuale di volte che è uscito testa su  19718 lanci è:  49.99492849173344 %
# La percentuale di volte che è uscito testa su  16449 lanci è:  49.820657790747156 %
# La percentuale di volte che è uscito testa su  11397 lanci è:  50.75019742037378 %
# La percentuale di volte che è uscito testa su  18494 lanci è:  49.799935114091056 %
# La percentuale di volte che è uscito testa su  15983 lanci è:  50.53494337733843 %
# La percentuale di volte che è uscito testa su  7566 lanci è:  49.59027227068464 %
# La percentuale di volte che è uscito testa su  12751 lanci è:  50.17645674849032 %
# La percentuale di volte che è uscito testa su  1598 lanci è:  51.06382978723404 %
# La percentuale di volte che è uscito testa su  11444 lanci è:  49.632995456134225 %
# La percentuale di volte che è uscito testa su  15826 lanci è:  50.43599140654619 %
# La percentuale di volte che è uscito testa su  1094 lanci è:  49.177330895795244 %
# La percentuale di volte che è uscito testa su  6578 lanci è:  49.75676497415628 %
# La percentuale di volte che è uscito testa su  17450 lanci è:  49.88538681948424 %
# La percentuale di volte che è uscito testa su  1298 lanci è:  50.154083204930664 %
# La percentuale di volte che è uscito testa su  12139 lanci è:  49.27918279924211 %
# La percentuale di volte che è uscito testa su  19694 lanci è:  50.23865136589825 %
# La percentuale di volte che è uscito testa su  5786 lanci è:  49.982716902868994 %
# La percentuale di volte che è uscito testa su  11443 lanci è:  49.261557283929044 %
# La percentuale di volte che è uscito testa su  17233 lanci è:  49.67794348053154 %
# La percentuale di volte che è uscito testa su  12033 lanci è:  50.32826394082939 %
# La percentuale di volte che è uscito testa su  6701 lanci è:  50.20146246828831 %
# La percentuale di volte che è uscito testa su  4268 lanci è:  49.48453608247423 %
# La percentuale di volte che è uscito testa su  2119 lanci è:  50.96743747050495 %
# La percentuale di volte che è uscito testa su  13289 lanci è:  50.08653773797877 %
# La percentuale di volte che è uscito testa su  568 lanci è:  48.59154929577465 %
# La percentuale di volte che è uscito testa su  19699 lanci è:  49.647190212701155 %
# La percentuale di volte che è uscito testa su  18640 lanci è:  50.06437768240344 %
# La percentuale di volte che è uscito testa su  12279 lanci è:  49.89820017916769 %
# La percentuale di volte che è uscito testa su  13995 lanci è:  49.68917470525188 %
# La percentuale di volte che è uscito testa su  1226 lanci è:  48.776508972267536 %
# La percentuale di volte che è uscito testa su  17653 lanci è:  50.410695065994446 %
# La percentuale di volte che è uscito testa su  19203 lanci è:  50.41399781284175 %
# La percentuale di volte che è uscito testa su  3768 lanci è:  50.477707006369435 %
# La percentuale di volte che è uscito testa su  3678 lanci è:  50.870038064165314 %
# La percentuale di volte che è uscito testa su  18972 lanci è:  49.868226860636724 %
# La percentuale di volte che è uscito testa su  17340 lanci è:  50.51326412918108 %
# La percentuale di volte che è uscito testa su  4346 lanci è:  49.332719742291765 %
# La percentuale di volte che è uscito testa su  19859 lanci è:  50.17372475955486 %
# La percentuale di volte che è uscito testa su  11986 lanci è:  50.19189053896213 %
# La percentuale di volte che è uscito testa su  13306 lanci è:  49.47392153915527 %
# La percentuale di volte che è uscito testa su  13559 lanci è:  50.38719669592153 %
# La percentuale di volte che è uscito testa su  10905 lanci è:  49.11508482347547 %
# La percentuale di volte che è uscito testa su  7004 lanci è:  49.643061107938316 %
# La percentuale di volte che è uscito testa su  8369 lanci è:  49.289042896403394 %
# La percentuale di volte che è uscito testa su  13016 lanci è:  49.900122925629994 %
# La percentuale di volte che è uscito testa su  1166 lanci è:  47.34133790737564 %
# La percentuale di volte che è uscito testa su  8953 lanci è:  49.10086004691165 %
# La percentuale di volte che è uscito testa su  9386 lanci è:  49.424675047943744 %
# La percentuale di volte che è uscito testa su  11438 lanci è:  50.42839657282742 %
# La percentuale di volte che è uscito testa su  19226 lanci è:  50.364090294393 %
# La percentuale di volte che è uscito testa su  8059 lanci è:  50.92443231170121 %
# La percentuale di volte che è uscito testa su  11346 lanci è:  50.43187026264763 %
# La percentuale di volte che è uscito testa su  15862 lanci è:  49.76673811625268 %
# La percentuale di volte che è uscito testa su  2029 lanci è:  50.172498767865946 %
# La percentuale di volte che è uscito testa su  10766 lanci è:  49.52628645736578 %
# La percentuale di volte che è uscito testa su  7609 lanci è:  50.361414114863976 %
# La percentuale di volte che è uscito testa su  9624 lanci è:  49.53241895261846 %
# La percentuale di volte che è uscito testa su  14954 lanci è:  50.2273639160091 %
# La percentuale di volte che è uscito testa su  19887 lanci è:  50.21873585759541 %
# La percentuale di volte che è uscito testa su  16183 lanci è:  49.74355805474881 %
# La percentuale di volte che è uscito testa su  14341 lanci è:  49.33407712153964 %
# La percentuale di volte che è uscito testa su  19568 lanci è:  50.189084219133285 %
# La percentuale di volte che è uscito testa su  15596 lanci è:  50.5770710438574 %
# La percentuale di volte che è uscito testa su  6499 lanci è:  50.46930296968765 %
# La percentuale di volte che è uscito testa su  112 lanci è:  50.89285714285714 %
# La percentuale di volte che è uscito testa su  11062 lanci è:  50.26215874163804 %
# La percentuale di volte che è uscito testa su  17986 lanci è:  50.59490715000556 %
# La percentuale di volte che è uscito testa su  6499 lanci è:  49.34605323895984 %
# La percentuale di volte che è uscito testa su  4646 lanci è:  49.28971157985364 %
# La percentuale di volte che è uscito testa su  620 lanci è:  50.0 %
# La percentuale di volte che è uscito testa su  19447 lanci è:  49.34951406386589 %
# La percentuale di volte che è uscito testa su  11414 lanci è:  50.595759593481695 %

# %% [markdown]
# ## 2. Analisi del Dataset Titanic
# - Quante righe e colonne ha il dataset?
# - Controlla quanti valori mancanti ci sono per colonna
# - Riempi i valori mancanti nella colonna 'Embarked' con il valore più frequente
# - Rimuovi le righe dove il valore di 'Age' è mancante
# - Controlla se ci sono righe duplicate
# - Calcola l'età media dei passeggeri per ogni classe (`Pclass`), se ci sono valori mancanti di età riempili con il valore medio
# - Visualizza la distribuzione dell'età per classe
# - Visualizza la distribuzione dell'età per classe dividendo e mmostrando insieme i dati di uomini e donne

# %%
# 📦 Caricamento del dataset
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

url = "https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv"
df = pd.read_csv(url)
#df.head()
print("Numero di righe: ", len(df))   # Numero di righe del dataset
print("Numero di colonne: ", len(df.columns))   # Numero di colonne del dataset
print("Numero di valori mancanti per colonna: \n", ((len(df)) - (df.count())))   # Numero di valori non nulli per colonna
# Riempi i valori mancanti nella colonna 'Embarked' con il valore più frequente
df["Embarked"].fillna(df["Embarked"].mode()[0], inplace=True)
# Rimouovi le righe dove il valore di 'age' è mancante
df.dropna(subset=["Age"], inplace=False)      #False perchè dopo i valori mancanti saranno sostituiti, per modificare il file si mette True
# Controlla se ci sono righe suplicate
print("Numero di righe duplicate: ", df.duplicated().sum())
# Calcola l'età media dei passeggeri per ogni classe (`Pclass`), se ci sono valori mancanti di età riempili con il valore medio
df["Age"]=df.groupby("Pclass")["Age"].apply(lambda x: x.fillna(x.mean()))  # Riempi i valori mancanti di 'Age' con la media per classe
# Visualizza la distribuzione dell'età per classe
sns.boxplot(data=df, y="Age", x="Pclass", color="red")
plt.title("Distribuzione dell'età per classe")
plt.xlabel("Classe")
plt.ylabel("Età")
plt.show()
# Visualizza la distribuzione dell'età per sesso con due grafici
sns.histplot(df[df["Sex"]=="male"]["Age"], x="Age", color="blue")
plt.title("Distribuzione dell'età per sesso maschile")
plt.xlabel("Età")
plt.ylabel("Frequenza")
plt.show()
sns.histplot(df[df["Sex"]=="female"]["Age"], x="Age", color="pink")
plt.title("Distribuzione dell'età per sesso femminile")
plt.xlabel("Età")
plt.ylabel("Frequenza")
plt.show()
# Visualizza la distribuzione dell'età per sesso con un unico grafico
sns.histplot(data=df, x="Age", hue="Sex", multiple="stack")
plt.title("Distribuzione dell'età per sesso")
plt.xlabel("Età")
plt.ylabel("Frequenza")
plt.show()
# Out:
# Numero di righe:  891
# Numero di colonne:  12
# Numero di valori mancanti per colonna:
#  PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64
# Numero di righe duplicate:  0
# Pclass
# 1    38.233441
# 2    29.877630
# 3    25.140620
# Name: Age, dtype: float64

# %% [markdown]
# ## 3. Analisi del Dataset Iris
#
# - Esplora la distribuzione delle specie (conta quanti campioni ci sono per specie)
# - Calcola la lunghezza e la larghezza media dei petali per specie
# - Visualizza le dimensioni dei petali per specie (scatterplot)
# - Crea una nuova colonna per l'area del petalo e analizzala
# - Grafico della distribuzione dell'area del petalo per specie (boxplot)

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

url = "https://raw.githubusercontent.com/mwaskom/seaborn-data/master/iris.csv"
df = pd.read_csv(url)
df.head()
# Quanti campioni ci sono per specie
df["species"].value_counts()
# Calcola la lunghezza e la larghwzza media dei petali per ogni specie
df.groupby("species")[["petal_length" ,"petal_width"]].mean()
# Visualizza le dimensioni dei petali per specie (scatterplot)
sns.scatterplot(data=df, x="petal_length", y="petal_width", hue="species")
plt.title("Dimensioni dei petali per specie")
plt.xlabel("Lunghezza del petalo")
plt.ylabel("Larghezza del petalo")
plt.show()
# Crea una nuova colonna per l'area del petalo e analizzala
df["area_petal"]=(df["petal_length"] * df["petal_width"])
df["area_petal"].describe()
# Grafico della distribuzione dell'area del petalo per specie (boxplot)
sns.boxplot(data=df, x="species", y="area_petal", hue="species")
plt.xlabel("Specie")
plt.ylabel("Area del petalo")
plt.title("Distribuzione dell'area del petalo per specie")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[46], line 14
#      12 df["area_petal"]=(df["petal_length"] * df["petal_width"])
#      13 # Visualizza le dimensioni dei petali per specie (scatterplot)
# ---> 14 sns.scatterplot(data=df, x="petal_length", y="petal_width", hue="species")
#      15 plt.title("Dimensioni dei petali per specie")
#      16 plt.xlabel("Lunghezza del petalo")
#
# NameError: name 'sns' is not defined
